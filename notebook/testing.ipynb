# %%
# This file is for testing purpose
from ragscript import ask_chatbot

answer = ask_chatbot("What was Amazon's operating income in 2023?")
print(answer)
# Out:
# Found 4 folders:
#
# 📁 amazon: 7 PDF(s)
#    - amazon 10-k 2023.pdf (781.8 KB)
#    - amazon 10-k 2024.pdf (736.9 KB)
#    - amazon 10-q q1 2024.pdf (478.2 KB)
#    - amazon 10-q q1 2025.pdf (474.9 KB)
#    - amazon 10-q q2 2024.pdf (497.4 KB)
#    - amazon 10-q q2 2025.pdf (497.0 KB)
#    - amazon 10-q q3 2024.pdf (1139.7 KB)
#
# 📁 apple: 6 PDF(s)
#    - apple 10-k 2023.pdf (788.4 KB)
#    - apple 10-k 2024.pdf (1068.2 KB)
#    - apple 10-q q1 2024.pdf (274.2 KB)
#    - apple 10-q q2 2024.pdf (325.6 KB)
#    - apple 10-q q4 2023.pdf (265.4 KB)
#    - apple 8-k q4 2023.pdf (99.0 KB)
#
# 📁 google: 7 PDF(s)
#    - google 10-k 2023.pdf (1339.6 KB)
#    - google 10-k 2024 (1).pdf (1308.9 KB)
#    - google 10-k 2024.pdf (1308.9 KB)
#    - google 10-q q1 2025.pdf (452.8 KB)
#    - google 10-q q2 2024.pdf (498.3 KB)
#    - google 10-q q2 2025.pdf (512.9 KB)
#    - google 10-q q3 2024.pdf (508.6 KB)
#
# 📁 meta: 7 PDF(s)
#    - meta 10-q q1 2024.pdf (240.1 KB)
#    - meta 10-q q1 2025.pdf (228.6 KB)
#    - meta 10-q q2 2024.pdf (148.5 KB)
#    - meta 10-q q2 2025.pdf (228.4 KB)
#    - meta 10-q q3 2024.pdf (226.5 KB)
#    - meta 10-q q3 2025.pdf (233.4 KB)
#    - meta 10-q q4 2024.pdf (228.5 KB)
#
# amazon 10-k 2023.pdf -> {'company': 'amazon', 'filing_type': '10-k', 'quarter': None, 'year': '2023', 'period': '2023'}
# apple 10-q q1 2024.pdf -> {'company': 'apple', 'filing_type': '10-q', 'quarter': 'Q1', 'year': '2024', 'period': 'Q1 2024'}
# meta 10-q q3 2025.pdf -> {'company': 'meta', 'filing_type': '10-q', 'quarter': 'Q3', 'year': '2025', 'period': 'Q3 2025'}
# apple 8-k q4 2023.pdf -> {'company': 'apple', 'filing_type': '8-k', 'quarter': 'Q4', 'year': '2023', 'period': 'Q4 2023'}
# google 8-k q2 2024.pdf -> {'company': 'google', 'filing_type': '8-k', 'quarter': 'Q2', 'year': '2024', 'period': 'Q2 2024'}
# Total unique PDFs to process: 26
# Skipped duplicates: ['google 10-k 2024.pdf']
# Loading weights: 100%|██████████| 103/103 [00:00<00:00, 2509.43it/s]
# Processing amazon 10-k 2023.pdf...
# Processing amazon 10-k 2024.pdf...
# Processing amazon 10-q q1 2024.pdf...
# Processing amazon 10-q q1 2025.pdf...
# Processing amazon 10-q q2 2024.pdf...
# Processing amazon 10-q q2 2025.pdf...
# Processing amazon 10-q q3 2024.pdf...
# Processing apple 10-k 2023.pdf...
# Processing apple 10-k 2024.pdf...
# Processing apple 10-q q1 2024.pdf...
# Processing apple 10-q q2 2024.pdf...
# Processing apple 10-q q4 2023.pdf...
# Processing apple 8-k q4 2023.pdf...
# Processing google 10-k 2023.pdf...
# Processing google 10-k 2024 (1).pdf...
# Processing google 10-q q1 2025.pdf...
# Processing google 10-q q2 2024.pdf...
# Processing google 10-q q2 2025.pdf...
# Processing google 10-q q3 2024.pdf...
# Processing meta 10-q q1 2024.pdf...
# Processing meta 10-q q1 2025.pdf...
# Processing meta 10-q q2 2024.pdf...
# Processing meta 10-q q2 2025.pdf...
# Processing meta 10-q q3 2024.pdf...
# Processing meta 10-q q3 2025.pdf...
# Processing meta 10-q q4 2024.pdf...
#
# Processed 26 files into 3016 chunks total
# Loading model: all-MiniLM-L6-v2
# Loading weights: 100%|██████████| 103/103 [00:00<00:00, 3271.76it/s]
# Model loaded. Embedding dimension: 384
# Generating embeddings for 3016 texts...
# Batches: 100%|██████████| 95/95 [01:48<00:00,  1.14s/it]
# Generated embeddings with shape: (3016, 384)
# (3016, 384)
# Connected to Postgres successfully!
# Vector extension ready.
# Embedding dimension: 384
# Table ready.
# Inserted 3016 chunks into Postgres.
# Total rows in table: 37992
# ('chunk_1eb9d950_0', 'amazon', '10-k', '2023', 'Table of Contents\nUNITED STATES\nSECURITIES AND EXCHANGE COMMISSION\nWashington, D.C. 20549\n\xa0_________')
# ('chunk_694daf7c_1', 'amazon', '10-k', '2023', '(Address and telephone number, including area code, of registrant’s principal executive offices)\nSec')
# ('chunk_fbef96db_2', 'amazon', '10-k', '2023', 'Indicate by check mark whether the registrant (1)\xa0has filed all reports required to be filed by Sect')
# ('chunk_380ff52a_3', 'amazon', '10-k', '2023', 'Indicate by check mark whether the registrant is a large accelerated filer, an accelerated filer, a ')
# ('chunk_4c55fdb3_4', 'amazon', '10-k', '2023', 'Indicate by check mark whether the registrant has filed a report on and attestation to its managemen')
# Generating embeddings for 1 texts...
# Batches: 100%|██████████| 1/1 [00:00<00:00, 49.37it/s]
# Generated embeddings with shape: (1, 384)
# Retrieved 5 documents
# meta Q3 2024 0.59
# Meta Earnings Presentation
# Q3 2024
# investor.fb.com
# ------------------------------------------------------------
# meta Q3 2024 0.59
# Meta Earnings Presentation
# Q3 2024
# investor.fb.com
# ------------------------------------------------------------
# meta Q3 2024 0.59
# Meta Earnings Presentation
# Q3 2024
# investor.fb.com
# ------------------------------------------------------------
# meta Q3 2024 0.59
# Meta Earnings Presentation
# Q3 2024
# investor.fb.com
# ------------------------------------------------------------
# meta Q3 2024 0.59
# Meta Earnings Presentation
# Q3 2024
# investor.fb.com
# ------------------------------------------------------------
# Key loaded: True
# Hello! How are you today? I hope you're having a great moment.
#
# Searching for: What was Apple's revenue in Q1 2024?
#
# Generating embeddings for 1 texts...
# Batches: 100%|██████████| 1/1 [00:00<00:00, 17.98it/s]
# Generated embeddings with shape: (1, 384)
# Retrieved 5 documents
# Using 5 retrieved chunks as context
#
# Based solely on the provided SEC filings context:
#
# Apple reported **$119.6 billion** in quarterly revenue for its fiscal 2024 first quarter ended December 30, 2023 (which corresponds to Apple's Q1 2024 results).
#
# **Citation**:
# - Apple 8-K filing for Q4 2023 (fiscal 2024 Q1 results), Exhibit 99.1 (all identical excerpts in the context).
# - Specific statement: *"The Company posted quarterly revenue of $119.6 billion, up 2 percent year over year."*
#
# This is explicitly stated in the context for Apple's fiscal 2024 first quarter (ended December 30, 2023), which is the Q1 2024 period under Apple's fiscal calendar.
#
# Searching for: Amazon FORM 10-K item 1
#
# Generating embeddings for 1 texts...
# Batches: 100%|██████████| 1/1 [00:00<00:00, 21.18it/s]
# Generated embeddings with shape: (1, 384)
# Retrieved 5 documents
# Using 5 retrieved chunks as context
#
# The context provided contains **no information about Amazon** or any Amazon SEC filings. All entries in the provided context are exclusively for **Apple Inc.'s 2024 Form 10-K** (repeated five times with identical summaries stating "None"). There is no mention of Amazon, Amazon's Form 10-K, or Item 1 (Business) in any of the provided filings.
#
# **Answer**: The context does not contain any information about Amazon or Amazon's Form 10-K. This answer is based solely on the provided SEC filings context, which is entirely focused on Apple Inc. (2024 Form 10-K).
#
# Searching for: What was Amazon's total net sales in 2023?
#
# Generating embeddings for 1 texts...
# Batches: 100%|██████████| 1/1 [00:00<00:00, 34.49it/s]
# Generated embeddings with shape: (1, 384)
# Retrieved 5 documents
# Using 5 retrieved chunks as context
#
# Based solely on the provided SEC filings context, Amazon's total net sales for 2023 were **$574,785 million**.
#
# This figure is explicitly stated in the **Amazon 10-K (2024)** filings (multiple identical sections provided in the context), under the "Consolidated" row for the "Year Ended December 31, 2023" period.
#
# **Citation**: Amazon 10-K (2024) filing (all sections consistently report this figure).
#
# Searching for: What are Amazon's three business segments
#
# Generating embeddings for 1 texts...
# Batches: 100%|██████████| 1/1 [00:00<00:00, 17.63it/s]
# Generated embeddings with shape: (1, 384)
# Retrieved 5 documents
# Using 5 retrieved chunks as context
#
# Based on the provided SEC filings, Amazon's three business segments are:
#
# North America, International, and Amazon Web Services ("AWS")
#
# This information appears consistently across all the provided Amazon 10-K filings for both 2023 and 2024. Each filing states: "We have organized our operations into three segments: North America, International, and Amazon Web Services ("AWS"). These segments reflect the way the Company evaluates its business performance and manages its operations."
#
# The answer is based on Amazon's 10-K SEC filings for 2023 and 2024, specifically in the section describing the company's business segments.
#
# Searching for: What was Amazon's operating income in 2023?
#
# Generating embeddings for 1 texts...
# Batches: 100%|██████████| 1/1 [00:00<00:00, 76.02it/s]
# Generated embeddings with shape: (1, 384)
# Retrieved 5 documents
# Using 5 retrieved chunks as context
#
# Based on the provided SEC filings context, Amazon's operating income in 2023 was $36.9 billion.
#
# This information is clearly stated in the Amazon 10-K filing for 2023: "Operating income was $12.2 billion and $36.9 billion for 2022 and 2023."
#
# The context also shows in the operating income table that the Consolidated Operating Income for 2023 was $36,852 million (which rounds to $36.9 billion), confirming this figure.
#
# Answer is based on: Amazon 10-K - 2023 filing (annual report) for the year ended December 31, 2023.
#
# Searching for: What was AWS segment's net sales in 2023?
#
# Generating embeddings for 1 texts...
# Batches: 100%|██████████| 1/1 [00:00<00:00, 63.59it/s]
# Generated embeddings with shape: (1, 384)
# Retrieved 5 documents
# Using 5 retrieved chunks as context
#
# Based solely on the provided SEC filings context, the AWS segment's net sales for 2023 were **$90,757 million** (as reported in millions).
#
# This figure is explicitly stated in the **Amazon 10-K filing for 2023** (all four identical sections provided in the context), under the "Net Sales" table for the year ended December 31, 2023. The table shows:
# **AWS**
# **2023** → **$90,757**
#
# **Citation**: Amazon 10-K (2023) filing, "Net Sales" section (Year Ended December 31, 2023 data).
#
# Searching for: Effective tax rate Q1 2024
#
# Generating embeddings for 1 texts...
# Batches: 100%|██████████| 1/1 [00:00<00:00, 74.14it/s]
# Generated embeddings with shape: (1, 384)
# Retrieved 5 documents
# Using 5 retrieved chunks as context
#
# Based solely on the provided SEC filings context, the effective tax rate for Q1 2024 is **13%**.
#
# **Citation**:
# - Company: META
# - Filing: 10-Q (Q3 2025)
# - Period: Q1'24 (Q1 2024)
# - Context: The table explicitly lists "Effective Tax Rate" as **13 %** for Q1'24 in all provided filings (see the "Effective Tax Rate" row under the period labels).
#
# *Note: The context shows identical data across all 5 filings, confirming consistency.*
#
# Searching for: Effective tax rate Q1 2024
#
# Generating embeddings for 1 texts...
# Batches: 100%|██████████| 1/1 [00:00<00:00, 66.08it/s]
# Generated embeddings with shape: (1, 384)
# Retrieved 5 documents
# Using 5 retrieved chunks as context
#
# Based solely on the provided SEC filings context:
#
# **Effective tax rate for Q1 2024 (Q1’24) is 13%.**
#
# *Source: META 10-Q filing for Q3 2025 (multiple identical sections provided), Effective Tax Rate table showing "Q1’24" with "13 %" in the Effective Tax Rate column.*
#
# Searching for: What was Amazon's operating income in 2023?
#
# Generating embeddings for 1 texts...
# Batches: 100%|██████████| 1/1 [00:00<00:00, 70.00it/s]
# Generated embeddings with shape: (1, 384)
# Retrieved 5 documents
# Using 5 retrieved chunks as context
#
# Based on the provided SEC filings, Amazon's operating income in 2023 was $36.9 billion.
#
# This information is clearly stated in the Amazon 10-K - 2023 filing: "Operating income was $12.2 billion and $36.9 billion for 2022 and 2023."
#
# The filing also shows this in the consolidated operating income table for the year ended December 31, 2023: "$36,852" million (which rounds to $36.9 billion).
#
# Answer is based on Amazon 10-K - 2023 filing for the year ended December 31, 2023.

# %%
answer = ask_chatbot("What was Amazon's free cash flow in 2023?")
print(answer)
# Out:
# Searching for: What was Amazon's free cash flow in 2023?
#
# Generating embeddings for 1 texts...
# Batches: 100%|██████████| 1/1 [00:00<00:00, 71.13it/s]
# Generated embeddings with shape: (1, 384)
# Retrieved 5 documents
# Using 5 retrieved chunks as context
#
# Based solely on the provided SEC filings context, Amazon's free cash flow for 2023 can be calculated as follows:
#
# **Free Cash Flow = Net cash provided by operating activities - Purchases of property and equipment (capital expenditures)**
#
# From the 2023 consolidated statements of cash flows (Amazon.com, Inc. 10-K filing):
# - Net cash provided by operating activities for 2023: **$84,946 million**
# - Purchases of property and equipment (cash used for capital expenditures) for 2023: **$52,729 million**
#
# **Calculation**:
# $84,946 million - $52,729 million = **$32,217 million**
#
# This calculation follows standard accounting practice for free cash flow (operating cash flow minus capital expenditures) and uses only the figures explicitly provided in the 2023 consolidated statements of cash flows section of Amazon's 10-K filing. The context does not define free cash flow separately, so this calculation is the appropriate method based on the available data.
#
# **Answer**: Amazon's free cash flow in 2023 was **$32,217 million** (based on Amazon.com, Inc. 10-K filing for 2023 consolidated statements of cash flows).

# %%
answer = ask_chatbot("was Meta's total revenue in Q2 2025, and how much of it came from the Family of Apps (FoA) segment?")
print(answer)
# Out:
# Searching for: was Meta's total revenue in Q2 2025, and how much of it came from the Family of Apps (FoA) segment?
#
# Generating embeddings for 1 texts...
# Batches: 100%|██████████| 1/1 [00:00<00:00, 22.83it/s]
# Generated embeddings with shape: (1, 384)
# Retrieved 5 documents
# Using 5 retrieved chunks as context
#
# Based solely on the provided SEC filings context:
#
# **Meta's total revenue in Q2 2025 was $47,516 million**, and **$47,146 million of it came from the Family of Apps (FoA) segment**.
#
# This answer is directly sourced from the **[META 10-Q - Q2 2025]** filing (the only SEC filing in the context that reports Q2 2025 results), where the "Total Revenue" row shows **$47,516** for Q2’25, and the "Family of Apps Revenue" row shows **$47,146** for Q2’25.
#
# *Note: All figures are in millions, as stated in the filing.*

# %%
answer = ask_chatbot("What was AWS segment's net sales in 2023?")
print(answer)
# Out:
# Searching for: What was AWS segment's net sales in 2023?
#
# Generating embeddings for 1 texts...
# Batches: 100%|██████████| 1/1 [00:00<00:00, 47.93it/s]
# Generated embeddings with shape: (1, 384)
# Retrieved 5 documents
# Using 5 retrieved chunks as context
#
# Based solely on the provided SEC filings context, the AWS segment's net sales for 2023 were **$90,757 million**.
#
# This figure is explicitly stated in the **Amazon 10-K filing for 2023** (all four identical sections in the context), under the "Net Sales" table for the year ended December 31, 2023. The context specifies:
# > **AWS**
# > **2023**
# > **$90,757**
#
# **Source**: Amazon 10-K (2023) filing, "Net Sales" section (Year Ended December 31, 2022–2023 data).
#
# Searching for: Effective tax rate Q1 2024
#
# Generating embeddings for 1 texts...
# Batches: 100%|██████████| 1/1 [00:00<00:00, 102.45it/s]
# Generated embeddings with shape: (1, 384)
# Retrieved 5 documents
# Using 5 retrieved chunks as context
#
# Based solely on the provided SEC filings context (all identical and from META's Q3 2025 10-Q filing), the effective tax rate for **Q1 2024** is **13%**.
#
# **Citation**:
# - Company: META
# - Filing: 10-Q (Q3 2025)
# - Period: Q1’24 (Q1 2024)
# - Context: The table explicitly lists "Effective Tax Rate" as **13%** for Q1’24, corresponding to $14,183 million in income before taxes and $1,814 million in provision for income taxes.
#
# *Note: The context does not contain any additional information that would alter this answer for Q1 2024.*
#
# Searching for: Effective tax rate Q1 2024
#
# Generating embeddings for 1 texts...
# Batches: 100%|██████████| 1/1 [00:00<00:00, 97.92it/s]
# Generated embeddings with shape: (1, 384)
# Retrieved 5 documents
# Using 5 retrieved chunks as context
#
# Based solely on the provided SEC filings context:
#
# **Effective tax rate for Q1 2024 is 13%**.
#
# This is explicitly stated in the *META 10-Q - Q3 2025* filing (all repeated sections show identical data), where the "Effective Tax Rate" row lists **13%** for **Q1’24** (Q1 2024).
#
# **Source**: META 10-Q (Q3 2025) filing, effective tax rate table (all 6 identical sections provided in context).

# %%
answer = ask_chatbot("Effective tax rate Q1 2024")
print(answer)

# %%
answer = ask_chatbot("Effective tax rate Q1 2024")
print(answer)
